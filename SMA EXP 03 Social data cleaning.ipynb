# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/AYUSH_YOUTUBE.csv")

print(data.head(20))
print(data.info())
# Out:
#     id                    author  \
# 0    1                  @MrBeast
# 1    2                @Oweeen188
# 2    3                @Dashzilla
# 3    4           @yakieboncookie
# 4    5                 @mapVNESE
# 5    6            @aguadeseaalex
# 6    7                @rjisp7000
# 7    8                @xoniz2451
# 8    9                  @JboVR69
# 9   10            @Creators_YT00
# 10  11       @kimberlynorrod6813
# 11  12          @user-ze9nz3et1c
# 12  13           @vinodbhuyar300
# 13  14              @Aatmkhoj123
# 14  15             @S4success433
# 15  16  @fardeensartandcraft1942
# 16  17            @EVILPANDA4321
# 17  18           @TanmayGaming19
# 18  19                  @rupvlgs
# 19  20  @fardeensartandcraft1942
#
#                                           description  \
# 0                      Go buy the new Feastables bar!
# 1                                                Goat
# 2                                                 YES
# 3                                               Maybe
# 4                                                Cool
# 5               When are Feastables coming to Mexico?
# 6                           Mythpat\'s voice is love❤
# 7     At 8:14 there is a shadow figure in the hallway
# 8                               umm guys look at 8:15
# 9                                                  My
# 10                                 Mr beast da goat 🐐
# 11                                      Bangla videos
# 12  Keep it up MYTHPAT , you are just PROOOOOOOOOO...
# 13       Ham Aisa kyon kr rhe hai - contant ke liye 😂
# 14                                        Mythpat ❤❤❤
# 15  Mythpat Bhaiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 16                 World best chocolate is feastable❤
# 17           your abandoned citys indias best city😂😂😂
# 18                                          Mythpat ❤
# 19                                            Mythpat
#
#                                                  guid        to  likecount  \
# 0                          Ugwz5dFRCALXvw25pMZ4AaABAg       NaN     135505
# 1   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0UkahbfZgb  @MrBeast       1356
# 2   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0Ukb-6Nqa5  @MrBeast        932
# 3   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0Ukb-jOfep  @MrBeast        712
# 4   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0UkbfiaLWy  @MrBeast        485
# 5   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0Ukbnted43  @MrBeast        596
# 6                          UgzZEvLxW5f1N8zPID54AaABAg       NaN          1
# 7                          UgxtK4lG4DXKiAedBel4AaABAg       NaN          0
# 8                          UgwN7KGqLrKmtor9XHt4AaABAg       NaN          0
# 9                          Ugx6dot5vvkiYZyk5O14AaABAg       NaN          0
# 10                         UgzTISl_eErVw-7Q2Vt4AaABAg       NaN          0
# 11                         UgwMfg76M5u367Og20V4AaABAg       NaN          0
# 12                         Ugzw-ErbCUDvcNf1psp4AaABAg       NaN          0
# 13                         UgwuMuQkyPIeMabzLQd4AaABAg       NaN          1
# 14                         UgxvsvgsR8RLTcq1D3x4AaABAg       NaN          0
# 15                         Ugz3yI3HofFok-MmBgh4AaABAg       NaN          0
# 16                         Ugy-woxHJxGjmxeaqG94AaABAg       NaN          0
# 17                         Ugxj0neO-JpRzNNGry54AaABAg       NaN          0
# 18                         Ugz6athsEPKwOPHKrSd4AaABAg       NaN          0
# 19                         Ugw_rIvHKEVyap792ax4AaABAg       NaN          0
#
#                                                  link              pubdate  \
# 0   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 11:59:45
# 1   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 12:00:14
# 2   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 12:00:17
# 3   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 12:00:17
# 4   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 12:00:23
# 5   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 12:00:23
# 6   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:39:30
# 7   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:37:40
# 8   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:36:20
# 9   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:31:00
# 10  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:30:32
# 11  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:30:14
# 12  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:29:48
# 13  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:29:42
# 14  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:29:29
# 15  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:28:03
# 16  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:26:43
# 17  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:25:41
# 18  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:22:32
# 19  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:19:20
#
#     replycount                                              title  \
# 0          750                     Go buy the new Feastables bar!
# 1            0                                               Goat
# 2            0                                                YES
# 3            0                                              Maybe
# 4            0                                               Cool
# 5            0              When are Feastables coming to Mexico?
# 6            0                          Mythpat\'s voice is love❤
# 7            0    At 8:14 there is a shadow figure in the hallway
# 8            0                              umm guys look at 8:15
# 9            0                                                 My
# 10           0                                 Mr beast da goat 🐐
# 11           0                                      Bangla videos
# 12           0  Keep it up MYTHPAT , you are just PROOOOOOOOOO...
# 13           0       Ham Aisa kyon kr rhe hai - contant ke liye 😂
# 14           0                                        Mythpat ❤❤❤
# 15           0  Mythpat Bhaiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 16           0                 World best chocolate is feastable❤
# 17           0           your abandoned citys indias best city😂😂😂
# 18           0                                          Mythpat ❤
# 19           0                                            Mythpat
#
#                                    authorChannelUrl  Unnamed: 11
# 0                   http://www.youtube.com/@MrBeast          NaN
# 1                 http://www.youtube.com/@Oweeen188          NaN
# 2                 http://www.youtube.com/@Dashzilla          NaN
# 3            http://www.youtube.com/@yakieboncookie          NaN
# 4                  http://www.youtube.com/@mapVNESE          NaN
# 5             http://www.youtube.com/@aguadeseaalex          NaN
# 6                 http://www.youtube.com/@rjisp7000          NaN
# 7                 http://www.youtube.com/@xoniz2451          NaN
# 8                   http://www.youtube.com/@JboVR69          NaN
# 9             http://www.youtube.com/@Creators_YT00          NaN
# 10       http://www.youtube.com/@kimberlynorrod6813          NaN
# 11          http://www.youtube.com/@user-ze9nz3et1c          NaN
# 12           http://www.youtube.com/@vinodbhuyar300          NaN
# 13              http://www.youtube.com/@Aatmkhoj123          NaN
# 14             http://www.youtube.com/@S4success433          NaN
# 15  http://www.youtube.com/@fardeensartandcraft1942          NaN
# 16            http://www.youtube.com/@EVILPANDA4321          NaN
# 17           http://www.youtube.com/@TanmayGaming19          NaN
# 18                  http://www.youtube.com/@rupvlgs          NaN
# 19  http://www.youtube.com/@fardeensartandcraft1942          NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2500 non-null   int64
#  1   author            2500 non-null   object
#  2   description       2495 non-null   object
#  3   guid              2500 non-null   object
#  4   to                91 non-null     object
#  5   likecount         2500 non-null   int64
#  6   link              2500 non-null   object
#  7   pubdate           2500 non-null   object
#  8   replycount        2500 non-null   int64
#  9   title             2495 non-null   object
#  10  authorChannelUrl  2500 non-null   object
#  11  Unnamed: 11       0 non-null      float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 234.5+ KB
# None

# %%
data.drop_duplicates(inplace=True)

# %%
print(data.head(20))
print(data.info())
# Out:
#     id                    author  \
# 0    1                  @MrBeast
# 1    2                @Oweeen188
# 2    3                @Dashzilla
# 3    4           @yakieboncookie
# 4    5                 @mapVNESE
# 5    6            @aguadeseaalex
# 6    7                @rjisp7000
# 7    8                @xoniz2451
# 8    9                  @JboVR69
# 9   10            @Creators_YT00
# 10  11       @kimberlynorrod6813
# 11  12          @user-ze9nz3et1c
# 12  13           @vinodbhuyar300
# 13  14              @Aatmkhoj123
# 14  15             @S4success433
# 15  16  @fardeensartandcraft1942
# 16  17            @EVILPANDA4321
# 17  18           @TanmayGaming19
# 18  19                  @rupvlgs
# 19  20  @fardeensartandcraft1942
#
#                                           description  \
# 0                      Go buy the new Feastables bar!
# 1                                                Goat
# 2                                                 YES
# 3                                               Maybe
# 4                                                Cool
# 5               When are Feastables coming to Mexico?
# 6                           Mythpat\'s voice is love❤
# 7     At 8:14 there is a shadow figure in the hallway
# 8                               umm guys look at 8:15
# 9                                                  My
# 10                                 Mr beast da goat 🐐
# 11                                      Bangla videos
# 12  Keep it up MYTHPAT , you are just PROOOOOOOOOO...
# 13       Ham Aisa kyon kr rhe hai - contant ke liye 😂
# 14                                        Mythpat ❤❤❤
# 15  Mythpat Bhaiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 16                 World best chocolate is feastable❤
# 17           your abandoned citys indias best city😂😂😂
# 18                                          Mythpat ❤
# 19                                            Mythpat
#
#                                                  guid        to  likecount  \
# 0                          Ugwz5dFRCALXvw25pMZ4AaABAg       NaN     135505
# 1   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0UkahbfZgb  @MrBeast       1356
# 2   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0Ukb-6Nqa5  @MrBeast        932
# 3   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0Ukb-jOfep  @MrBeast        712
# 4   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0UkbfiaLWy  @MrBeast        485
# 5   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0Ukbnted43  @MrBeast        596
# 6                          UgzZEvLxW5f1N8zPID54AaABAg       NaN          1
# 7                          UgxtK4lG4DXKiAedBel4AaABAg       NaN          0
# 8                          UgwN7KGqLrKmtor9XHt4AaABAg       NaN          0
# 9                          Ugx6dot5vvkiYZyk5O14AaABAg       NaN          0
# 10                         UgzTISl_eErVw-7Q2Vt4AaABAg       NaN          0
# 11                         UgwMfg76M5u367Og20V4AaABAg       NaN          0
# 12                         Ugzw-ErbCUDvcNf1psp4AaABAg       NaN          0
# 13                         UgwuMuQkyPIeMabzLQd4AaABAg       NaN          1
# 14                         UgxvsvgsR8RLTcq1D3x4AaABAg       NaN          0
# 15                         Ugz3yI3HofFok-MmBgh4AaABAg       NaN          0
# 16                         Ugy-woxHJxGjmxeaqG94AaABAg       NaN          0
# 17                         Ugxj0neO-JpRzNNGry54AaABAg       NaN          0
# 18                         Ugz6athsEPKwOPHKrSd4AaABAg       NaN          0
# 19                         Ugw_rIvHKEVyap792ax4AaABAg       NaN          0
#
#                                                  link              pubdate  \
# 0   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 11:59:45
# 1   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 12:00:14
# 2   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 12:00:17
# 3   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 12:00:17
# 4   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 12:00:23
# 5   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-02 12:00:23
# 6   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:39:30
# 7   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:37:40
# 8   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:36:20
# 9   https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:31:00
# 10  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:30:32
# 11  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:30:14
# 12  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:29:48
# 13  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:29:42
# 14  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:29:29
# 15  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:28:03
# 16  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:26:43
# 17  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:25:41
# 18  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:22:32
# 19  https://www.youtube.com/watch?v=tWYsfOSY9vY&lc...  2024-03-19 02:19:20
#
#     replycount                                              title  \
# 0          750                     Go buy the new Feastables bar!
# 1            0                                               Goat
# 2            0                                                YES
# 3            0                                              Maybe
# 4            0                                               Cool
# 5            0              When are Feastables coming to Mexico?
# 6            0                          Mythpat\'s voice is love❤
# 7            0    At 8:14 there is a shadow figure in the hallway
# 8            0                              umm guys look at 8:15
# 9            0                                                 My
# 10           0                                 Mr beast da goat 🐐
# 11           0                                      Bangla videos
# 12           0  Keep it up MYTHPAT , you are just PROOOOOOOOOO...
# 13           0       Ham Aisa kyon kr rhe hai - contant ke liye 😂
# 14           0                                        Mythpat ❤❤❤
# 15           0  Mythpat Bhaiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 16           0                 World best chocolate is feastable❤
# 17           0           your abandoned citys indias best city😂😂😂
# 18           0                                          Mythpat ❤
# 19           0                                            Mythpat
#
#                                    authorChannelUrl  Unnamed: 11
# 0                   http://www.youtube.com/@MrBeast          NaN
# 1                 http://www.youtube.com/@Oweeen188          NaN
# 2                 http://www.youtube.com/@Dashzilla          NaN
# 3            http://www.youtube.com/@yakieboncookie          NaN
# 4                  http://www.youtube.com/@mapVNESE          NaN
# 5             http://www.youtube.com/@aguadeseaalex          NaN
# 6                 http://www.youtube.com/@rjisp7000          NaN
# 7                 http://www.youtube.com/@xoniz2451          NaN
# 8                   http://www.youtube.com/@JboVR69          NaN
# 9             http://www.youtube.com/@Creators_YT00          NaN
# 10       http://www.youtube.com/@kimberlynorrod6813          NaN
# 11          http://www.youtube.com/@user-ze9nz3et1c          NaN
# 12           http://www.youtube.com/@vinodbhuyar300          NaN
# 13              http://www.youtube.com/@Aatmkhoj123          NaN
# 14             http://www.youtube.com/@S4success433          NaN
# 15  http://www.youtube.com/@fardeensartandcraft1942          NaN
# 16            http://www.youtube.com/@EVILPANDA4321          NaN
# 17           http://www.youtube.com/@TanmayGaming19          NaN
# 18                  http://www.youtube.com/@rupvlgs          NaN
# 19  http://www.youtube.com/@fardeensartandcraft1942          NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 2499
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2500 non-null   int64
#  1   author            2500 non-null   object
#  2   description       2495 non-null   object
#  3   guid              2500 non-null   object
#  4   to                91 non-null     object
#  5   likecount         2500 non-null   int64
#  6   link              2500 non-null   object
#  7   pubdate           2500 non-null   object
#  8   replycount        2500 non-null   int64
#  9   title             2495 non-null   object
#  10  authorChannelUrl  2500 non-null   object
#  11  Unnamed: 11       0 non-null      float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 253.9+ KB
# None

# %%
import re

def clean_text(text):
    # Remove URLs
    text = re.sub(r'https://www.youtube.com/watch?v=', '..', text)
    text = re.sub(r'[https://www.youtube.com/watch?v=]', '', text)
    # Remove special characters and punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Convert to lowercase
    text = text.lower()
    return text

# %%
# data.drop('pubdate', inplace=True, axis=1)

data.drop('to', inplace=True, axis=1)

# %%
data['author'] = data['author'].apply(clean_text)

data['link'] = data['link'].apply(clean_text)

# %%
data['authorChannelUrl'] = data['authorChannelUrl'].apply(clean_text)

# %%
import re

def clean_text(text):
    # Check if the input is a string or NaN, and return an empty string if not
    if isinstance(text, str):
        # Remove URLs
        text = re.sub(r'http\S+', '', text)
        # Remove special characters and punctuation
        text = re.sub(r'[^\w\s]', '', text)
        # Remove numbers
        text = re.sub(r'\d+', '', text)
        # Convert to lowercase
        text = text.lower()
        return text
    else:
        return ""

# Apply the modified clean_text function to the 'description' column
data['description'] = data['description'].apply(clean_text)
data['title'] = data['title'].apply(clean_text)

# %%
print(data.head(20))
# Out:
#     id     author                                        description  \
# 0    1        mrb                      go buy the new feastables bar
# 1    2         on                                               goat
# 2    3      dzill                                                yes
# 3    4      kinki                                              maybe
# 4    5      vnese                                               cool
# 5    6       gdlx               when are feastables coming to mexico
# 6    7        rji                             mythpats voice is love
# 7    8       xniz        at  there is a shadow figure in the hallway
# 8    9        jvr                                  umm guys look at
# 9   10     crr_yt                                                 my
# 10  11   kirlnrrd                                  mr beast da goat
# 11  12       rznz                                      bangla videos
# 12  13       indr  keep it up mythpat  you are just prooooooooooo...
# 13  14        akj         ham aisa kyon kr rhe hai  contant ke liye
# 14  15          s                                           mythpat
# 15  16  frdnrndrf  mythpat bhaiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 16  17  evilpanda                  world best chocolate is feastable
# 17  18     tnging              your abandoned citys indias best city
# 18  19        rlg                                           mythpat
# 19  20  frdnrndrf                                            mythpat
#
#                                                  guid  likecount  \
# 0                          Ugwz5dFRCALXvw25pMZ4AaABAg     135505
# 1   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0UkahbfZgb       1356
# 2   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0Ukb-6Nqa5        932
# 3   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0Ukb-jOfep        712
# 4   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0UkbfiaLWy        485
# 5   Ugwz5dFRCALXvw25pMZ4AaABAg.A0UkY9ZHPYlA0Ukbnted43        596
# 6                          UgzZEvLxW5f1N8zPID54AaABAg          1
# 7                          UgxtK4lG4DXKiAedBel4AaABAg          0
# 8                          UgwN7KGqLrKmtor9XHt4AaABAg          0
# 9                          Ugx6dot5vvkiYZyk5O14AaABAg          0
# 10                         UgzTISl_eErVw-7Q2Vt4AaABAg          0
# 11                         UgwMfg76M5u367Og20V4AaABAg          0
# 12                         Ugzw-ErbCUDvcNf1psp4AaABAg          0
# 13                         UgwuMuQkyPIeMabzLQd4AaABAg          1
# 14                         UgxvsvgsR8RLTcq1D3x4AaABAg          0
# 15                         Ugz3yI3HofFok-MmBgh4AaABAg          0
# 16                         Ugy-woxHJxGjmxeaqG94AaABAg          0
# 17                         Ugxj0neO-JpRzNNGry54AaABAg          0
# 18                         Ugz6athsEPKwOPHKrSd4AaABAg          0
# 19                         Ugw_rIvHKEVyap792ax4AaABAg          0
#
#                                          link              pubdate  \
# 0                   wyfosyylugzdfrcalxmzaabag  2024-03-02 11:59:45
# 1    wyfosyylugzdfrcalxmzaabagaukyzhpylaukfzg  2024-03-02 12:00:14
# 2     wyfosyylugzdfrcalxmzaabagaukyzhpylauknq  2024-03-02 12:00:17
# 3    wyfosyylugzdfrcalxmzaabagaukyzhpylaukjof  2024-03-02 12:00:17
# 4   wyfosyylugzdfrcalxmzaabagaukyzhpylaukfilw  2024-03-02 12:00:23
# 5     wyfosyylugzdfrcalxmzaabagaukyzhpylauknd  2024-03-02 12:00:23
# 6                 wyfosyylugzzelxwfnzpidaabag  2024-03-19 02:39:30
# 7                 wyfosyylugxklgdxkiadblaabag  2024-03-19 02:37:40
# 8                   wyfosyylugnkgqlrkrxhaabag  2024-03-19 02:36:20
# 9                     wyfosyylugxdkiyzkoaabag  2024-03-19 02:31:00
# 10                 wyfosyylugztisl_ervqvaabag  2024-03-19 02:30:32
# 11                     wyfosyylugmfgmogvaabag  2024-03-19 02:30:14
# 12                    wyfosyylugzercudnfaabag  2024-03-19 02:29:48
# 13                  wyfosyylugmqkpimzlqdaabag  2024-03-19 02:29:42
# 14                   wyfosyylugxgrrltqdxaabag  2024-03-19 02:29:29
# 15                   wyfosyylugzihffkmbgaabag  2024-03-19 02:28:03
# 16                   wyfosyylugxhjxgjxqgaabag  2024-03-19 02:26:43
# 17                 wyfosyylugxjnojrznngraabag  2024-03-19 02:25:41
# 18                 wyfosyylugzepkophkrsdaabag  2024-03-19 02:22:32
# 19                    wyfosyylug_rihkevxaabag  2024-03-19 02:19:20
#
#     replycount                                              title  \
# 0          750                      go buy the new feastables bar
# 1            0                                               goat
# 2            0                                                yes
# 3            0                                              maybe
# 4            0                                               cool
# 5            0               when are feastables coming to mexico
# 6            0                             mythpats voice is love
# 7            0        at  there is a shadow figure in the hallway
# 8            0                                  umm guys look at
# 9            0                                                 my
# 10           0                                  mr beast da goat
# 11           0                                      bangla videos
# 12           0  keep it up mythpat  you are just prooooooooooo...
# 13           0         ham aisa kyon kr rhe hai  contant ke liye
# 14           0                                           mythpat
# 15           0  mythpat bhaiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 16           0                  world best chocolate is feastable
# 17           0              your abandoned citys indias best city
# 18           0                                           mythpat
# 19           0                                            mythpat
#
#    authorChannelUrl  Unnamed: 11
# 0               mrb          NaN
# 1                on          NaN
# 2             dzill          NaN
# 3             kinki          NaN
# 4             vnese          NaN
# 5              gdlx          NaN
# 6               rji          NaN
# 7              xniz          NaN
# 8               jvr          NaN
# 9            crr_yt          NaN
# 10         kirlnrrd          NaN
# 11             rznz          NaN
# 12             indr          NaN
# 13              akj          NaN
# 14                s          NaN
# 15        frdnrndrf          NaN
# 16        evilpanda          NaN
# 17           tnging          NaN
# 18              rlg          NaN
# 19        frdnrndrf          NaN

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 2499
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2500 non-null   int64
#  1   author            2500 non-null   object
#  2   description       2500 non-null   object
#  3   guid              2500 non-null   object
#  4   likecount         2500 non-null   int64
#  5   link              2500 non-null   object
#  6   pubdate           2500 non-null   object
#  7   replycount        2500 non-null   int64
#  8   title             2500 non-null   object
#  9   authorChannelUrl  2500 non-null   object
#  10  Unnamed: 11       0 non-null      float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 234.4+ KB
# None
